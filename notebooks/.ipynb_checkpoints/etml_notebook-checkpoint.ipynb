# %%
import pandas as pd

from pandarallel import pandarallel

from freeholdforecast.tasks.etml_task import ETMLTask

pd.options.display.max_columns = 100

etml_task = ETMLTask()
# Out:
# INFO: Pandarallel will run on 5 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/home/vscode/.local/share/virtualenvs/freehold-forecast-zrIN4e5_/lib/python3.8/site-packages/pyspark/jars/spark-unsafe_2.12-3.2.1.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# ...

# %%
etml_task.get_df_raw()
etml_task.df_raw
# Out:
# 2022-08-30 17:19:24,686 - INFO - ETMLTask - Retrieving data
# INFO:ETMLTask:Retrieving data
# 2022-08-30 17:19:26,528 - INFO - ETMLTask - Successfully retrieved data
# INFO:ETMLTask:Successfully retrieved data
#        Conveyance #  Year of Sale # of Parcels Sold  Building Value  \
# 0            857834          1998                 2               0
# 1            832520          1998                 1           24900
# 2            853002          1998                 1           24100
# 3            856026          1998                 1           24100
# 4            860492          1998                 2               0
# ...             ...           ...               ...             ...
# 456028       304304          2022                 1          354380
# 456029       304561          2022                 1          137880
# 456030       291320          2022                 1          139330
# 456031       306214          2022                 1               0
# ...

# %%
etml_task.get_df_ready()
etml_task.df_ready
# Out:
# 2022-08-30 17:19:26,571 - INFO - ETMLTask - Preparing data
# INFO:ETMLTask:Preparing data
# 2022-08-30 17:19:40,659 - INFO - ETMLTask - Successfully prepared data
# INFO:ETMLTask:Successfully prepared data
#          will_sell_next_two_years       year  dates_since_last_sale  \
# 0                               1 1998-01-01                      0
# 1                               0 1999-01-01                      0
# 2                               0 2000-01-01                      1
# 3                               0 2001-01-01                      2
# 4                               0 2002-01-01                      3
# ...                           ...        ...                    ...
# 4766837                         0 2021-01-01                      0
# 4766838                         0 2021-01-01                      0
# 4766839                         0 2021-01-01                      0
# 4766840                         0 2021-01-01                      0
# ...

# %%
etml_task.get_df_encoded()
etml_task.df_encoded
# Out:
# 2022-08-30 17:19:40,695 - INFO - ETMLTask - Encoding data
# INFO:ETMLTask:Encoding data
# ...

# %%
etml_task.train_model()
